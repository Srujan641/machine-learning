# %%
import pandas as  pd
from matplotlib import pyplot as ptl

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#     age  incurance
# 0    21          0
# 1    28          0
# 2    34          0
# 3    39          1
# 4    41          1
# 5    45          1
# 6    50          0
# 7    55          0
# 8    60          1
# 9    61          1
# 10   64          1
# 11   69          1
# 12   72          1
# 13   78          1
# 14   82          1

# %%
x=df.age
y=df.incurance

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train ,x_test, y_train ,y_test= train_test_split(df[['age']],df.incurance,test_size=0.2)
x_test
# Out:
#     age
# 0    21
# 10   64
# 3    39

# %%
model=LogisticRegression()
model.fit(x_train,y_train) # trainiong the model
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test) #accuracy
# Out:
# 0.6666666666666666

# %%
ptl.scatter(df.age,df.incurance) #ploting the graoph
